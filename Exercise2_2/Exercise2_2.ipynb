# %% [markdown]
# #### Dependencies and libraries for the exercise

# %%
import os, zipfile, json, hashlib
from PIL import Image
import pytesseract
from oletools.olevba import VBA_Parser
from docx import Document
import pandas as pd

# %% [markdown]
# #### Functions: Hash File

# %%
def sha256_hash(file_path):
    
    with open(file_path, "rb") as f:
        return hashlib.sha256(f.read()).hexdigest()

# %% [markdown]
# #### Detect the macros of the Office Documents

# %%
def detect_macros(file_path):
    
    result = {"has_macros": False, "macro_snippets": []}
    try:
        vbaparser = VBA_Parser(file_path)
        if vbaparser.detect_vba_macros():
            result["has_macros"] = True
            for (_, _, _, vba_code) in vbaparser.extract_macros():
                snippet = vba_code[:300] if vba_code else ""
                result["macro_snippets"].append(snippet)
        vbaparser.close()
    except Exception as e:
        result["error"] = str(e)
    return result

# %% [markdown]
# #### Extract the images

# %%
def extract_images(file_path):

    image_dir = "extracted_images"
    os.makedirs(image_dir, exist_ok=True)
    extracted = []

    try:
        with zipfile.ZipFile(file_path, 'r') as docx:
            for item in docx.namelist():
                if item.startswith("word/media/"):
                    image_name = os.path.basename(item)
                    out_path = os.path.join(image_dir, image_name)
                    with open(out_path, "wb") as f:
                        f.write(docx.read(item))
                    extracted.append(out_path)
    except Exception as e:
        print(f"Error extracting images: {e}")
    return extracted

# %% [markdown]
# #### Use OCR to extract the images

# %%
def ocr_images(image_paths):
    
    results = {}
    for img_path in image_paths:
        try:
            text = pytesseract.image_to_string(Image.open(img_path))
            results[os.path.basename(img_path)] = text.strip()
        except Exception as e:
            results[os.path.basename(img_path)] = f"OCR Error: {e}"
    return results

# %% [markdown]
# #### Analyze the document

# %%
def analyze_office_file(file_path):
    
    print(f"[*] Analyzing: {file_path}")

    sha256 = sha256_hash(file_path)
    macros = detect_macros(file_path)
    images = extract_images(file_path)
    ocr_results = ocr_images(images)

    report = {
        "file_name": os.path.basename(file_path),
        "sha256": sha256,
        "has_macros": macros.get("has_macros", False),
        "macro_snippets": macros.get("macro_snippets", []),
        "images_found": len(images),
        "ocr_results": ocr_results
    }

    return report

# %% [markdown]
# #### Analyze all files

# %%
folder_path = "msoffice"
reports = []

for filename in os.listdir(folder_path):
    if filename.lower().endswith((".doc", ".docx", ".docm")):
        file_path = os.path.join(folder_path, filename)
        report = analyze_office_file(file_path)
        reports.append(report)

# Save full report as JSON
with open("msoffice_analysis_report.json", "w") as f:
    json.dump(reports, f, indent=4)
# Out:
# [*] Analyzing: msoffice/1bdbb2a88fc9b48a4d29ae76aafadf16.docx
# [*] Analyzing: msoffice/240c5875a9ba744f6c61ff42a4d7d999.docx
# [*] Analyzing: msoffice/46b138cf8645b457b2a8c4ebc79e06f1.docx

# %% [markdown]
# #### Results

# %%
import pprint
pprint.pprint(reports)
# Out:
# [{'file_name': '1bdbb2a88fc9b48a4d29ae76aafadf16.docx',
#   'has_macros': True,
#   'images_found': 2,
#   'macro_snippets': ['Attribute VB_Name = "ThisDocument"\r\n'
#                      'Attribute VB_Base = "1Normal.ThisDocument"\r\n'
#                      'Attribute VB_GlobalNameSpace = False\r\n'
#                      'Attribute VB_Creatable = False\r\n'
#                      'Attribute VB_PredeclaredId = True\r\n'
#                      'Attribute VB_Exposed = True\r\n'
#                      'Attribute VB_TemplateDerived = True\r\n'
#                      'Attribute VB_Customizable = True\r\n',
#                      'Attribute VB_Name = "encountered"\r\n'
#                      'Private Const STARTF_USESHOWWINDOW& = &H1\r\n'
#                      'Private Const NORMAL_PRIORITY_CLASS = &H20&\r\n'
#                      'Private Const INFINITE = -1&\r\n'
#                      '\r\n'
#                      'Private Type STARTUPINFO\r\n'
#                      '    cb As Long\r\n'
#                      '    lpReserved As String\r\n'
#                      '    lpDesktop As String\r\n'
#                      '    lpTitle As String\r\n'
#                      '    dwX As Long\r\n'
#                      '    dwY As L',
#                      'Attribute VB_Name = "suggestions"\r\n'
#                      'Attribute VB_Base = '
#                      '"0{8110565B-91F3-472A-8873-1277EB16E094}{CF590736-BF5B-4356-BDD7-BE5E39D8FD76}"\r\n'
#                      'Attribute VB_GlobalNameSpace = False\r\n'
#                      'Attribute VB_Creatable = False\r\n'
#                      'Attribute VB_PredeclaredId = True\r\n'
#                      'Attribute VB_Exposed = False\r\n'
#                      'Attribute VB_TemplateDerived ',
#                      'Attribute VB_Name = "visualizations"\r\n'
#                      '\r\n'
#                      '\r\n'
#                      '#If VBA7 Then\r\n'
#                      '\r\n'
#                      '\r\n'
#                      ' Declare PtrSafe Function AllocConsole Lib "kernel32" () '
#                      'As LongPtr\r\n'
#                      ' Declare PtrSafe Function FreeConsole Lib "kernel32" () '
#                      'As LongPtr\r\n'
#                      '    Declare PtrSafe Function CloseHandle Lib "kernel32" '
#                      '(ByVal hObject As LongPtr) As LongPtr\r\n'
#                      '    Dec',
#                      'Attribute VB_Name = "gradient"\r\n'
#                      'Attribute VB_Base = '
#                      '"0{8E2242A5-8D7E-4112-A29B-0E07ACD379DE}{584BB7D4-B90F-410E-B74C-486294B13CF5}"\r\n'
#                      'Attribute VB_GlobalNameSpace = False\r\n'
#                      'Attribute VB_Creatable = False\r\n'
#                      'Attribute VB_PredeclaredId = True\r\n'
#                      'Attribute VB_Exposed = False\r\n'
#                      'Attribute VB_TemplateDerived = F',
#                      'Attribute VB_Name = "FoldEpic"\r\n'
#                      'Attribute VB_Base = '
#                      '"0{049455BE-FC6A-4DDB-B0AD-5311BCFABA96}{C9A561EC-38FC-4A0A-ABA2-3A0994A7BDCA}"\r\n'
#                      'Attribute VB_GlobalNameSpace = False\r\n'
#                      'Attribute VB_Creatable = False\r\n'
#                      'Attribute VB_PredeclaredId = True\r\n'
#                      'Attribute VB_Exposed = False\r\n'
#                      'Attribute VB_TemplateDerived = F',
#                      'Attribute VB_Name = "CdInfoComponate"\r\n'
#                      'Attribute VB_Base = '
#                      '"0{43824E85-4F49-4566-8893-53D20C818EC6}{EFB76C6C-E716-4740-90A5-698018E9E8B3}"\r\n'
#                      'Attribute VB_GlobalNameSpace = False\r\n'
#                      'Attribute VB_Creatable = False\r\n'
#                      'Attribute VB_PredeclaredId = True\r\n'
#                      'Attribute VB_Exposed = False\r\n'
#                      'Attribute VB_TemplateDeri'],
#   'ocr_results': {'image1.png': 'This document was created with an older\n'
#                                 'version of Microsoft Office\n'
#                                 '\n'
#                                 'This document is only availible for desktop '
#                                 'and laptop versions of\n'
#                                 'Microsoft Office Word.\n'
#                                 '\n'
#                                 'Click “Enable editing" button from the yellow '
#                                 'bar above\n'
#                                 '\n'
#                                 'Once you have enabled editing, please click '
#                                 '"Enable content"\n'
#                                 'button from the yellow bar above',
#                   'image2.png': 'This document was created with an older\n'
#                                 'version of Microsoft Office\n'
#                                 '\n'
#                                 'This document is only availible for desktop '
#                                 'and laptop versions of\n'
#                                 'Microsoft Office Word.\n'
#                                 '\n'
#                                 'Click “Enable editing" button from the yellow '
#                                 'bar above\n'
#                                 '\n'
#                                 'Once you have enabled editing, please click '
#                                 '"Enable content"\n'
#                                 'button from the yellow bar above'},
#   'sha256': 'c30977d86a5f4e84a84435a29580c7bf39f1f5818fcb1d521d0028195cb0582a'},
#  {'file_name': '240c5875a9ba744f6c61ff42a4d7d999.docx',
#   'has_macros': True,
#   'images_found': 4,
#   'macro_snippets': ['Attribute VB_Name = "ThisDocument"\r\n'
#                      'Attribute VB_Base = "1Normal.ThisDocument"\r\n'
#                      'Attribute VB_GlobalNameSpace = False\r\n'
#                      'Attribute VB_Creatable = False\r\n'
#                      'Attribute VB_PredeclaredId = True\r\n'
#                      'Attribute VB_Exposed = True\r\n'
#                      'Attribute VB_TemplateDerived = True\r\n'
#                      'Attribute VB_Customizable = True\r\n'
#                      'Attribute VB_Co'],
#   'ocr_results': {'image1.png': 'ee ee: Doct_NEW_LAST22343 [Compatibility '
#                                 'Mode] - Word PICTURE TOOLS\n'
#                                 'HOME INSERT DESIGN —-PAGELAYOUT REFERENCES = '
#                                 'MAILINGS | REVIEW | VIEW FORMAT\n'
#                                 'R\n'
#                                 '\n'
#                                 'LN} P "\n'
#                                 'v I [EE] Ags ev KE So BS Sint vanup y A £) '
#                                 'Previous & fa\n'
#                                 '\n'
#                                 'SH E&\n'
#                                 '\n'
#                                 '‘ow Markup > Dy Net\n'
#                                 'Spelling & Define Thesaurus Word Translate '
#                                 'Language New Delete Previous Nex Show Track. '
#                                 'Accept Reject Compare Block Restrict\n'
#                                 'Grammar Count = ~ Comment Comments Changes '
#                                 '[BI Reviewing Pane ~ Authors Editing\n'
#                                 'Proofing language Comments Tracking & Changes '
#                                 'Compare Protect\n'
#                                 'B| g t 4\n'
#                                 'LI Ba Copy\n'
#                                 'Paste . BI U-a&x, x / £\n'
#                                 '+ Format Painter =\n'
#                                 'Clipboard GS Font & Paragraph\n'
#                                 '\n'
#                                 'Enable Content\n'
#                                 '\n'
#                                 '———> °\n'
#                                 '\n'
#                                 'ns npocmotpa Bcex COCHOBHbIX U3MeHEHN, '
#                                 'HarxKMUTe KHonky Enable Content\n'
#                                 '(BknrounTb cofepKumMoe)\n'
#                                 '\n'
#                                 '7H - ax\n'
#                                 '\n'
#                                 'signin FO\n'
#                                 '\n'
#                                 'Taka',
#                   'image2.wmf': 'OCR Error: Unsupported image format/type',
#                   'image3.wmf': 'OCR Error: Unsupported image format/type',
#                   'image4.png': ''},
#   'sha256': 'd57acf8eb7c1d9b23299042ccac8a7f16cb185994232827993cee8b212c68702'},
#  {'file_name': '46b138cf8645b457b2a8c4ebc79e06f1.docx',
#   'has_macros': True,
#   'images_found': 1,
#   'macro_snippets': ['Attribute VB_Name = "ThisDocument"\r\n'
#                      'Attribute VB_Base = "1Normal.ThisDocument"\r\n'
#                      'Attribute VB_GlobalNameSpace = False\r\n'
#                      'Attribute VB_Creatable = False\r\n'
#                      'Attribute VB_PredeclaredId = True\r\n'
#                      'Attribute VB_Exposed = True\r\n'
#                      'Attribute VB_TemplateDerived = True\r\n'
#                      'Attribute VB_Customizable = True\r\n',
#                      'Attribute VB_Name = "EjRhGuEWGBOUE"\r\n'
#                      'Public lus(0 To 2623) As String\r\n'
#                      'Function QWERWRERQ()\r\n'
#                      'ZXCPIO\r\n'
#                      'ILPUZZZZZRTY = FreeFile\r\n'
#                      'Dim Bytes() As Byte\r\n'
#                      'Dim RWEIOPAL As Integer\r\n'
#                      'Open Environ(DRTYUIUU("*;5,H*>G?D)C(7@")) & '
#                      'DRTYUIUU("*H*>8*NNG2*O16-*6B.-") For Binary Lock Write '
#                      'As #ILPUZZZZZRTY\r\n'
#                      'For I = LBou',
#                      'Attribute VB_Name = "ZDUHFOWERUHFOPW"\r\n'
#                      'Function AAB(sd)\r\n'
#                      '    For I = 0 To sd\r\n'
#                      '     Selection.TypeText Text:=" "\r\n'
#                      '     Selection.TypeBackspace\r\n'
#                      '     Selection.TypeBackspace\r\n'
#                      '     Selection.TypeBackspace\r\n'
#                      '     Selection.TypeBackspace\r\n'
#                      '     Selection.TypeBackspace\r\n'
#                      '     Selection.TypeBackspace\r\n'
#                      ' Next\r\n',
#                      'Attribute VB_Name = "EWRJKLGJHRUIE"\r\n'
#                      'Function DRTYUIUU(ByVal bbbb)\r\n'
#                      'output = ""\r\n'
#                      'c = 0\r\n'
#                      'r = 1\r\n'
#                      'While r < 16777215\r\n'
#                      'r = r * 40\r\n'
#                      'c = c + 1\r\n'
#                      'Wend\r\n'
#                      'For I = 1 To Len(bbbb)\r\n'
#                      'Value = Value * 40 + (Asc(Mid(bbbb, I, 1)) - 40)\r\n'
#                      'If I Mod c = 0 Then\r\n'
#                      'While Value > 0\r\n'
#                      'v = Value Mod 256\r\n'
#                      'If v > 0 Then\r\n'
#                      'output = C',
#                      'Attribute VB_Name = "JDFRTZAQW"\r\n'
#                      'Attribute VB_Base = '
#                      '"0{3F2C085D-3F7E-49AB-8065-83831A9EF0F7}{8BF7F07B-2B1D-43A5-9AFF-EDF2045CBFAB}"\r\n'
#                      'Attribute VB_GlobalNameSpace = False\r\n'
#                      'Attribute VB_Creatable = False\r\n'
#                      'Attribute VB_PredeclaredId = True\r\n'
#                      'Attribute VB_Exposed = False\r\n'
#                      'Attribute VB_TemplateDerived = ',
#                      'Attribute VB_Name = "AQYUIBN"\r\n'
#                      'Attribute VB_Base = '
#                      '"0{EF286235-1376-4350-B5A9-F4BA512CA67C}{C2900608-78A5-487C-865D-87B16FAEDF1B}"\r\n'
#                      'Attribute VB_GlobalNameSpace = False\r\n'
#                      'Attribute VB_Creatable = False\r\n'
#                      'Attribute VB_PredeclaredId = True\r\n'
#                      'Attribute VB_Exposed = False\r\n'
#                      'Attribute VB_TemplateDerived = Fa',
#                      'Attribute VB_Name = "KYUFGREFFG"\r\n'
#                      'Attribute VB_Base = '
#                      '"0{6AA60754-875A-479C-8662-E8E12A9EF246}{BCA17F11-075E-44C9-A4C3-CFD6AE4B808F}"\r\n'
#                      'Attribute VB_GlobalNameSpace = False\r\n'
#                      'Attribute VB_Creatable = False\r\n'
#                      'Attribute VB_PredeclaredId = True\r\n'
#                      'Attribute VB_Exposed = False\r\n'
#                      'Attribute VB_TemplateDerived =',
#                      'Attribute VB_Name = "QWERTYASCV"\r\n'
#                      'Attribute VB_Base = '
#                      '"0{E0939A0A-8B4A-4183-BF5E-91715ECA6475}{CEEFB67C-C910-4A4E-B73B-6877ADC649AB}"\r\n'
#                      'Attribute VB_GlobalNameSpace = False\r\n'
#                      'Attribute VB_Creatable = False\r\n'
#                      'Attribute VB_PredeclaredId = True\r\n'
#                      'Attribute VB_Exposed = False\r\n'
#                      'Attribute VB_TemplateDerived =',
#                      'Attribute VB_Name = "BASDUYTE"\r\n'
#                      'Attribute VB_Base = '
#                      '"0{3720F548-CFBB-4389-ABA2-5AB3859F8DE3}{20B1A28D-AC50-40A7-80FC-EB3C5948C7A2}"\r\n'
#                      'Attribute VB_GlobalNameSpace = False\r\n'
#                      'Attribute VB_Creatable = False\r\n'
#                      'Attribute VB_PredeclaredId = True\r\n'
#                      'Attribute VB_Exposed = False\r\n'
#                      'Attribute VB_TemplateDerived = F',
#                      'Attribute VB_Name = "CDWKUYGASZXCXERGF"\r\n'
#                      'Attribute VB_Base = '
#                      '"0{DA0B4820-8436-416F-9AC0-97E180726369}{3A53419E-B586-4B18-8461-C9AC4E1BA65F}"\r\n'
#                      'Attribute VB_GlobalNameSpace = False\r\n'
#                      'Attribute VB_Creatable = False\r\n'
#                      'Attribute VB_PredeclaredId = True\r\n'
#                      'Attribute VB_Exposed = False\r\n'
#                      'Attribute VB_TemplateDe',
#                      'Attribute VB_Name = "WEERRTTY"\r\n'
#                      'Attribute VB_Base = '
#                      '"0{EB227229-33A0-44FA-8FDC-119826A1E19A}{8FB5357F-FF17-4859-A30E-8F7CDE0FA728}"\r\n'
#                      'Attribute VB_GlobalNameSpace = False\r\n'
#                      'Attribute VB_Creatable = False\r\n'
#                      'Attribute VB_PredeclaredId = True\r\n'
#                      'Attribute VB_Exposed = False\r\n'
#                      'Attribute VB_TemplateDerived = F',
#                      'Attribute VB_Name = "XCVBASQWW"\r\n'
#                      'Attribute VB_Base = '
#                      '"0{C1A6F6C7-A132-40AC-9D5F-F5746405C0E0}{3C292EF4-26C3-489C-A904-4B948E80683F}"\r\n'
#                      'Attribute VB_GlobalNameSpace = False\r\n'
#                      'Attribute VB_Creatable = False\r\n'
#                      'Attribute VB_PredeclaredId = True\r\n'
#                      'Attribute VB_Exposed = False\r\n'
#                      'Attribute VB_TemplateDerived = ',
#                      'Attribute VB_Name = "RUYIRTGFGTGFG"\r\n'
#                      'Function fibonacci(ByVal zahl As Long)\r\n'
#                      '\r\n'
#                      'If zahl = 0 Then\r\n'
#                      '        fibonacci = 0\r\n'
#                      'End If\r\n'
#                      '\r\n'
#                      'If zahl = 1 Then\r\n'
#                      '        fibonacci = 1\r\n'
#                      'End If\r\n'
#                      '\r\n'
#                      'Dim a, b, c, c_tmp As Long\r\n'
#                      'a = 0\r\n'
#                      'b = 1\r\n'
#                      'c = 0\r\n'
#                      'For I = 2 To zahl\r\n'
#                      '        c_tmp = c\r\n'
#                      '        c = a + b\r\n'
#                      '        a = b'],
#   'ocr_results': {'image1.jpeg': '1) Office 365\n'
#                                  'This document created in online version of '
#                                  'Microsoft Office Word\n'
#                                  '\n'
#                                  'To view or edit this document, please click '
#                                  '"Enable editing” button\n'
#                                  '‘on the top yellow bar, and then click '
#                                  '"Enable content”'},
#   'sha256': '745b0e0793fc507d9e1ad7155beb7ac48f8a556e6ef06e43888cbefec3083f2f'}]

# %% [markdown]
# ### Display the results

# %%
import pandas as pd

summary_data = []

for report in reports:
    summary_data.append({
        "File Name": report["file_name"],
        "SHA256": report["sha256"],
        "Has Macros": report["has_macros"],
        "Number of Images": report["images_found"],
        "OCR Extracted Text": "\n".join([f"{k}: {v[:50]}..." 
                                         for k, v in report["ocr_results"].items()])
    })

df_summary = pd.DataFrame(summary_data)

df_summary
# Out:
#                                File Name  \
# 0  1bdbb2a88fc9b48a4d29ae76aafadf16.docx
# 1  240c5875a9ba744f6c61ff42a4d7d999.docx
# 2  46b138cf8645b457b2a8c4ebc79e06f1.docx
#
#                                               SHA256  Has Macros  \
# 0  c30977d86a5f4e84a84435a29580c7bf39f1f5818fcb1d...        True
# 1  d57acf8eb7c1d9b23299042ccac8a7f16cb18599423282...        True
# 2  745b0e0793fc507d9e1ad7155beb7ac48f8a556e6ef06e...        True
#
#    Number of Images                                 OCR Extracted Text
# 0                 2  image2.png: This document was created with an ...
# 1                 4  image3.wmf: OCR Error: Unsupported image forma...
# 2                 1  image1.jpeg: 1) Office 365\nThis document crea...
